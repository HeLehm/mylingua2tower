# %%
from src.utils.mind import get_mind_train, get_mind_val, get_hprarams
from src.iterator import MINDIterator
from src.nrms import NRMSModel

# %%
MIND_type = 'demo'
seed = 42

# %% [markdown]
# ### downlaod data

# %%
t_news, t_behaviors = get_mind_train(MIND_type)
v_news, v_behaviors = get_mind_val(MIND_type)
hparams = get_hprarams(MIND_type)
hparams
# Out:
# HParams object with values {'support_quick_scoring': True, 'dropout': 0.2, 'attention_hidden_dim': 200, 'head_num': 20, 'head_dim': 20, 'filter_num': 200, 'window_size': 3, 'vert_emb_dim': 100, 'subvert_emb_dim': 100, 'gru_unit': 400, 'type': 'ini', 'user_emb_dim': 50, 'learning_rate': 0.0001, 'optimizer': 'adam', 'epochs': 10, 'batch_size': 32, 'show_step': 100000, 'title_size': 30, 'his_size': 50, 'data_format': 'news', 'npratio': 4, 'metrics': ['group_auc', 'mean_mrr', 'ndcg@5;10'], 'word_emb_dim': 300, 'model_type': 'nrms', 'loss': 'cross_entropy_loss', 'wordEmb_file': '/Users/hanslehmann/Documents/PythonFiles/mylingua/mylingua2tower/src/data/GloVe/glove.6B.300d_padded.npy', 'wordDict_file': '/Users/hanslehmann/Documents/PythonFiles/mylingua/mylingua2tower/src/data/GloVe/glove.6B.300d_idx_padded.pkl', 'userDict_file': '/Users/hanslehmann/Documents/PythonFiles/mylingua/mylingua2tower/src/data/MIND/demo/utils/uid2index.pkl', 'glove_name': 'glove.6B'}

# %%
iterator = MINDIterator
model = NRMSModel(hparams, iterator, seed=seed)
# Out:
# 2023-02-02 19:05:33.102126: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /usr/local/lib/python3.9/site-packages/recommenders/models/newsrec/models/base_model.py:68: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/wd/tmzjl_qj7yn6tvqn_dyxqgym0000gn/T/ipykernel_9619/298386533.py in <module>
#       1 iterator = MINDIterator
# ----> 2 model = NRMSModel(hparams, iterator, seed=seed)
#
# /usr/local/lib/python3.9/site-packages/recommenders/models/newsrec/models/nrms.py in __init__(self, hparams, iterator_creator, seed)
#      42         self.word2vec_embedding = self._init_embedding(hparams.wordEmb_file)
#      43
# ---> 44         super().__init__(
#      45             hparams,
#      46             iterator_creator,
#
# /usr/local/lib/python3.9/site-packages/recommenders/models/newsrec/models/base_model.py in __init__(self, hparams, iterator_creator, seed)
#      70         # IMPORTANT: models have to be loaded AFTER SETTING THE SESSION for keras!
#      71         # Otherwise, their weights will be unavailable in the threads after the session there has been set
# ---> 72         self.model, self.scorer = self._build_graph()
#      73
#      74         self.loss = self._get_loss()
#
# /usr/local/lib/python3.9/site-packages/recommenders/models/newsrec/models/nrms.py in _build_graph(self)
#      92             object: a model used to evaluate and inference.
#      93         """
# ---> 94         model, scorer = self._build_nrms()
#      95         return model, scorer
#      96
#
# /usr/local/lib/python3.9/site-packages/recommenders/models/newsrec/models/nrms.py in _build_nrms(self)
#     178         self.newsencoder = titleencoder
#     179
# --> 180         user_present = self.userencoder(his_input_title)
#     181         news_present = layers.TimeDistributed(self.newsencoder)(pred_input_title)
#     182         news_present_one = self.newsencoder(pred_title_one_reshape)
#
# /usr/local/lib/python3.9/site-packages/keras/engine/base_layer_v1.py in __call__(self, *args, **kwargs)
#     763               with autocast_variable.enable_auto_cast_variables(
#     764                   self._compute_dtype_object):
# --> 765                 outputs = call_fn(cast_inputs, *args, **kwargs)
#     766
#     767             except tf.errors.OperatorNotAllowedInGraphError as e:
#
# /usr/local/lib/python3.9/site-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     412         a list of tensors if there are more than one outputs.
#     413     """
# --> 414     return self._run_internal_graph(
#     415         inputs, training=training, mask=mask)
#     416
#
# /usr/local/lib/python3.9/site-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# /usr/local/lib/python3.9/site-packages/keras/engine/base_layer_v1.py in __call__(self, *args, **kwargs)
#     793                                                       outputs)
#     794           self._handle_activity_regularization(inputs, outputs)
# --> 795           self._set_mask_metadata(inputs, outputs, input_masks)
#     796           if hasattr(self, '_set_inputs') and not self.inputs:
#     797             # Subclassed network: explicitly set metadata normally set by
#
# /usr/local/lib/python3.9/site-packages/keras/engine/base_layer_v1.py in _set_mask_metadata(self, inputs, outputs, previous_mask)
#    1934       flat_masks = [None for _ in flat_outputs]
#    1935     else:
# -> 1936       output_masks = self.compute_mask(inputs, previous_mask)
#    1937       # `compute_mask` can return a single `None` even when a Layer
#    1938       # has multiple outputs.
#
# /usr/local/lib/python3.9/site-packages/keras/layers/wrappers.py in compute_mask(self, inputs, mask)
#     342     inner_inputs = tf.__internal__.nest.map_structure_up_to(inputs, tf.reshape, inputs,
#     343                                             inner_input_shape)
# --> 344     output_mask = self.layer.compute_mask(inner_inputs, inner_mask)
#     345     if output_mask is None:
#     346       if mask is None:
#
# /usr/local/lib/python3.9/site-packages/keras/engine/functional.py in compute_mask(self, inputs, mask)
#     389     # by itself because it will duplicate any updates and losses in graph
#     390     # mode by `call`ing the Layers again.
# --> 391     output_tensors = self._run_internal_graph(inputs, mask=mask)
#     392     return tf.nest.map_structure(lambda t: getattr(t, '_keras_mask', None),
#     393                               output_tensors)
#
# /usr/local/lib/python3.9/site-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# /usr/local/lib/python3.9/site-packages/keras/engine/base_layer_v1.py in __call__(self, *args, **kwargs)
#     763               with autocast_variable.enable_auto_cast_variables(
#     764                   self._compute_dtype_object):
# --> 765                 outputs = call_fn(cast_inputs, *args, **kwargs)
#     766
#     767             except tf.errors.OperatorNotAllowedInGraphError as e:
#
# /usr/local/lib/python3.9/site-packages/keras/layers/core.py in call(self, inputs, training)
#     210           rate=self.rate)
#     211
# --> 212     output = control_flow_util.smart_cond(training, dropped_inputs,
#     213                                           lambda: tf.identity(inputs))
#     214     return output
#
# /usr/local/lib/python3.9/site-packages/keras/utils/control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     103     return tf.cond(
#     104         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105   return tf.__internal__.smart_cond.smart_cond(
#     106       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     107
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      58       return false_fn()
#      59   else:
# ---> 60     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#      61                                  name=name)
#      62
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     547                 'in a future version' if date is None else ('after %s' % date),
#     548                 instructions)
# --> 549       return func(*args, **kwargs)
#     550
#     551     doc = _add_deprecated_arg_notice_to_docstring(
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/ops/control_flow_ops.py in cond(pred, true_fn, false_fn, strict, name, fn1, fn2)
#    1252   # Always enable control flow v2 if building a function, regardless of toggle.
#    1253   if util.EnableControlFlowV2(ops.get_default_graph()):
# -> 1254     return cond_v2.cond_v2(pred, true_fn, false_fn, name)
#    1255
#    1256   with ops.name_scope(name, "cond", [pred]):
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/ops/cond_v2.py in cond_v2(pred, true_fn, false_fn, name)
#      80       pred = array_ops.squeeze_v2(pred)
#      81
# ---> 82     true_graph = func_graph_module.func_graph_from_py_func(
#      83         true_name,
#      84         true_fn, [], {},
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.9/site-packages/keras/layers/core.py in dropped_inputs()
#     204
#     205     def dropped_inputs():
# --> 206       return tf.nn.dropout(
#     207           inputs,
#     208           noise_shape=self._get_noise_shape(inputs),
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/ops/nn_ops.py in dropout_v2(x, rate, noise_shape, seed, name)
#    5332         keep_prob = 1 - rate
#    5333         scale = 1 / keep_prob
# -> 5334         scale = ops.convert_to_tensor(scale, dtype=x_dtype)
#    5335         ret = gen_math_ops.mul(x, scale)
#    5336       else:
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     291   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     292   attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 293   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     294       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     295
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     597       inp = self.capture(inp)
#     598       captured_inputs.append(inp)
# --> 599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     600         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     601         compute_device)
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3559     # Session.run call cannot occur between creating and mutating the op.
#    3560     with self._mutation_lock():
# -> 3561       ret = Operation(
#    3562           node_def,
#    3563           self,
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2039       if op_def is None:
#    2040         op_def = self._graph._get_op_def(node_def.op)
# -> 2041       self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2042                                 control_input_ops, op_def)
#    2043       name = compat.as_str(node_def.name)
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1874     # TODO(skyewm): this creates and deletes a new TF_Status for every attr.
#    1875     # It might be worth creating a convenient way to re-use the same status.
# -> 1876     pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1877                                            serialized)
#    1878
#
# KeyboardInterrupt:

# %%
model.fit(t_news, t_behaviors, v_news, v_behaviors)
